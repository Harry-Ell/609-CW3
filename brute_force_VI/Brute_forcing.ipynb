# %% [markdown]
# # Playing around with the problem

# %%
import sys 
sys.path.append('..')

# %%
# my packages
from brute_force_VI.probability_generator import Probability_Generator
from brute_force_VI.rewards_generator import Rewarder
from brute_force_VI.MDP import GenericMDP
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 from brute_force_VI.probability_generator import Probability_Generator
#       3 from brute_force_VI.rewards_generator import Rewarder
# ----> 4 from brute_force_VI.MDP import GenericMDP
#
# File ~/Documents/RT2/609-CW3/brute_force_VI/../brute_force_VI/MDP.py:5
#       1 '''
#       2 Heavily trimmed submission from cw2, should be lightweight
#       3 '''
# ----> 5 import numpy as np
#       6 import matplotlib.pyplot as plt
#       9 class GenericMDP:
#
# ModuleNotFoundError: No module named 'numpy'

# %%
ps = Probability_Generator(6, 100)()
rs = Rewarder(6, 100)()

# %% [markdown]
# may aswell just see if this works

# %%
# we could tidy up the api a lot to make it so that we dont have to define all these extra things 
game_size = 100
dice_size = 6
states = [(i, j, k) for i in range(game_size) for j in range(game_size) for k in range(game_size)]
actions = [0, 1]
discount_rate = 1
max_iterations = 100

# %%
value_iteration = GenericMDP(states=states, 
                 actions = actions,
                 probabilities=ps, 
                 rewards=rs, 
                 discount_rate=discount_rate, 
                 max_iterations=max_iterations, 
                 tolerance = 1e-6)()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 value_iteration = GenericMDP(states=states,
#       2                  actions = actions,
#       3                  probabilities=ps,
#       4                  rewards=rs,
#       5                  discount_rate=discount_rate,
#       6                  max_iterations=max_iterations,
#       7                  tolerance = 1e-6)()
#
# File c:\Users\ellinghh\Documents\609-CW3\dev_steps\..\brute_force_VI\MDP.py:161, in GenericMDP.__call__(self)
#     156 def __call__(self):
#     157     '''
#     158     Call funciton, allowing us to interact with instances of the class like a function.
#     159     '''
# --> 161     self.values = self._value_iteration()
#     162     self.policy = self._extract_policy()
#     164     return self.policy, self.values
#
# File c:\Users\ellinghh\Documents\609-CW3\dev_steps\..\brute_force_VI\MDP.py:115, in GenericMDP._value_iteration(self)
#     113 V_k_minus_1 = V_k.copy()
#     114 for state in self.states:
# --> 115     V_k[state] = self._bellmans_eq(state = state, values_dict = V_k_minus_1)
#     116 k += 1
#     117 # lets see if we have reached tolerance, only after doing multiple iterations through incase of a slow start
#
# File c:\Users\ellinghh\Documents\609-CW3\dev_steps\..\brute_force_VI\MDP.py:75, in GenericMDP._bellmans_eq(self, state, values_dict, extract_policy)
#      73 ev = 0.0
#      74 for s_prime, prob in self.probabilities[state][a].items():
# ---> 75     reward = self.rewards_dict.get(state, {}).get(a, {}).get(s_prime, 0)
#      77     # ---------- did the turn pass? ----------
#      78     turn_passes = (
#      79         (a == 0)                                    # stick
#      80         or (a == 1 and s_prime[2] == 0)             # hit & rolled a 1
#      81     )
#
# KeyboardInterrupt:

# %%
policy = value_iteration[0]

# %%
import numpy as np
import plotly.graph_objects as go

def plot_highest_hit_surface(V: dict, target_score: int = 100):
    """
    Plots the highest value of z (turn total) for which V[x,y,z] == 1 before flipping to 0.
    This shows how aggressive the policy is — how far you're willing to roll.
    """
    PS = OS = target_score
    MAX_TURN = target_score * 2  # extra margin

    X = np.arange(PS)
    Y = np.arange(OS)
    Z = np.full((PS, OS), np.nan)

    for x in range(PS):
        for y in range(OS):
            z_hit = None
            for z in range(MAX_TURN):
                if V.get((x, y, z), 0) == 0:
                    z_hit = z - 1
                    break
            if z_hit is not None and z_hit >= 0:
                Z[x, y] = z_hit

    X_grid, Y_grid = np.meshgrid(X, Y, indexing='ij')

    fig = go.Figure(data=[go.Surface(
        z=Z,
        x=X_grid,
        y=Y_grid,
        colorscale='RdYlGn',
        colorbar=dict(title="Highest Hit Turn Total"),
        showscale=True
    )])

    fig.update_layout(
        scene=dict(
            xaxis=dict(title='Opponent Score'),
            yaxis=dict(title='Player Score'),
            zaxis=dict(title='Highest Turn Total Rolled'),
        ),
        title="Aggressiveness Surface: Highest Hit Value Before Hold",
        width=900,
        height=750
    )

    fig.show()

# %%
import pickle

with open('my_dict.pkl', 'rb') as f:
    policy = pickle.load(f)

plot_highest_hit_surface(policy, 100)
